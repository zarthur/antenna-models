# %% [markdown]
# # Coiled Antenna for 160 Meters
#
# Created with assistance from ChatGPT

# %% [markdown]
# ## Generating the Geometry
#
# To model the antenna, we'll need to define a geometry. I'll use [4nec2](https://www.qsl.net/4nec2/) to help validate the generated geometry.

# %%
from support import generate_antenna_geometry_4nec2

# %%
freq = 1_900_000  # 1.9 MHz, 160 Meters
geometry = generate_antenna_geometry_4nec2(freq)

# %%
geometry
# Out:
#      Type   Tag  Segs        x1        y1         z1        x2        y2  \
# 0      GW     1    21  0.075000  0.000000 -39.446376  0.071665  0.022117
# 1      GW     2    21  0.071665  0.022117 -39.423931  0.061955  0.042267
# 2      GW     3    21  0.061955  0.042267 -39.401487  0.046736  0.058658
# 3      GW     4    21  0.046736  0.058658 -39.379042  0.027359  0.069832
# 4      GW     5    21  0.027359  0.069832 -39.356598  0.005550  0.074794
# ...   ...   ...   ...       ...       ...        ...       ...       ...
# 3510   GW  3511    21  0.011709  0.074080  39.334153 -0.010657  0.074239
# 3511   GW  3512    21 -0.010657  0.074239  39.356598 -0.032076  0.067795
# 3512   GW  3513    21 -0.032076  0.067795  39.379042 -0.050642  0.055321
# 3513   GW  3514    21 -0.050642  0.055321  39.401487 -0.064704  0.037926
# 3514   GW  3515    21 -0.064704  0.037926  39.423931  0.075000  0.000000
#
#              z2  Radius
# 0    -39.423931   0.001
# 1    -39.401487   0.001
# 2    -39.379042   0.001
# 3    -39.356598   0.001
# 4    -39.334153   0.001
# ...         ...     ...
# 3510  39.356598   0.001
# 3511  39.379042   0.001
# 3512  39.401487   0.001
# 3513  39.423931   0.001
# 3514  39.446376   0.001
#
# [3515 rows x 10 columns]
